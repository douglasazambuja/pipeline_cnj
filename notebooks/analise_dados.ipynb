# %%
path = '../data/datajud_dados.json'
import pandas as pd 
import json

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)
# pd.set_option('display.max_colwidth', None)

# pd.reset_option("display.width")
pd.reset_option("display.max_colwidth")

# %%
with open(path) as f:
    data = json.load(f)

df = pd.json_normalize(data)
df.head()
# Out:
#    took  timed_out  _shards.total  _shards.successful  _shards.skipped  \
# 0   344      False              7                   7                0
#
#    _shards.failed  hits.total.value hits.total.relation  hits.max_score  \
# 0               0             10000                 gte             1.0
#
#                                            hits.hits
# 0  [{'_index': 'api_publica_trf1', '_id': 'TRF1_G...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   took                 1 non-null      int64
#  1   timed_out            1 non-null      bool
#  2   _shards.total        1 non-null      int64
#  3   _shards.successful   1 non-null      int64
#  4   _shards.skipped      1 non-null      int64
#  5   _shards.failed       1 non-null      int64
#  6   hits.total.value     1 non-null      int64
#  7   hits.total.relation  1 non-null      str
#  8   hits.max_score       1 non-null      float64
#  9   hits.hits            1 non-null      object
# dtypes: bool(1), float64(1), int64(6), object(1), str(1)
# memory usage: 205.0+ bytes
